# %%
from m21.osc import play_bass, play, sorted_elems_by_offset, unpitched_mapping

# %%
play("/bass", sorted_elems_by_offset, unpitched_mapping, 1)
# Out:
# <coroutine object play at 0x77f3d6804f60>
